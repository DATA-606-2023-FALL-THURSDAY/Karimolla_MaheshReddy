# %%
import pandas as pd

# %%
data_2009 = pd.read_csv('2009.csv')

# %%
data_2009
# Out:
#             FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0        2009-01-01         XE               1204    DCA  EWR          1100
# 1        2009-01-01         XE               1206    EWR  IAD          1510
# 2        2009-01-01         XE               1207    EWR  DCA          1100
# 3        2009-01-01         XE               1208    DCA  EWR          1240
# 4        2009-01-01         XE               1209    IAD  EWR          1715
# ...             ...        ...                ...    ...  ...           ...
# 6429333  2009-12-31         YV               2846    YUM  PHX           615
# 6429334  2009-12-31         YV               2850    YUM  PHX          1929
# 6429335  2009-12-31         YV               2866    YUM  PHX          1400
# 6429336  2009-12-31         YV               2868    YUM  PHX          1620
# 6429337  2009-12-31         YV               2871    YUM  PHX          1123
#
# ...

# %%
data_2010 = pd.read_csv('2010.csv')

# %%
data_2010
# Out:
#             FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0        2010-01-01         MQ               4438    LGA  RDU          1940
# 1        2010-01-01         MQ               4440    DCA  JFK           950
# 2        2010-01-01         MQ               4443    LGA  RDU           900
# 3        2010-01-01         MQ               4445    RDU  LGA          1940
# 4        2010-01-01         MQ               4447    JFK  DCA          2035
# ...             ...        ...                ...    ...  ...           ...
# 6450112  2010-12-31         US               2175    LGA  DCA          1300
# 6450113  2010-12-31         US               2176    DCA  LGA          1500
# 6450114  2010-12-31         US               2183    LGA  DCA          1700
# 6450115  2010-12-31         US               2184    DCA  LGA          1900
# 6450116  2010-12-31         US               2191    LGA  DCA          2100
#
# ...

# %%
data_2011 = pd.read_csv('2011.csv')
data_2011
# Out:
#             FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0        2011-01-01         MQ               4529    BOS  JFK          1830
# 1        2011-01-01         MQ               4532    BNA  DCA          1100
# 2        2011-01-01         MQ               4532    DCA  JFK          1400
# 3        2011-01-01         MQ               4537    RDU  JFK          1710
# 4        2011-01-01         MQ               4540    CMH  LGA          1340
# ...             ...        ...                ...    ...  ...           ...
# 6066645  2011-12-31         US               2138    LGA  BOS          1800
# 6066646  2011-12-31         US               2168    DCA  LGA          1100
# 6066647  2011-12-31         US               2175    LGA  DCA          1300
# 6066648  2011-12-31         US               2176    DCA  LGA          1500
# 6066649  2011-12-31         US               2183    LGA  DCA          1700
#
# ...

# %%
data_2012 = pd.read_csv('2012.csv')
data_2012
# Out:
#             FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0        2012-01-01         MQ               4041    BMI  ORD        1715.0
# 1        2012-01-01         MQ               4041    ORD  BMI        1545.0
# 2        2012-01-01         MQ               4042    SGF  ORD         715.0
# 3        2012-01-01         MQ               4045    ORD  DBQ        1535.0
# 4        2012-01-01         MQ               4047    ORD  RIC        1600.0
# ...             ...        ...                ...    ...  ...           ...
# 6096757  2012-12-31         YV               1036    HNL  KOA        1600.0
# 6096758  2012-12-31         YV               1054    HNL  KOA        1252.0
# 6096759  2012-12-31         YV               1004    HNL  LIH        1300.0
# 6096760  2012-12-31         YV               1005    HNL  LIH        1500.0
# 6096761  2012-12-31         YV               1017    HNL  LIH        1700.0
#
# ...

# %%
data_2013 = pd.read_csv('2013.csv')
data_2013
# Out:
#             FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0        2013-01-01         VX                108    LAX  IAD           700
# 1        2013-01-01         VX                114    LAX  IAD          2205
# 2        2013-01-01         VX                 11    JFK  SFO           730
# 3        2013-01-01         VX                121    PHL  LAX           700
# 4        2013-01-01         VX                124    LAX  PHL          1100
# ...             ...        ...                ...    ...  ...           ...
# 6369477  2013-12-31         MQ               3271    IND  ORD          1100
# 6369478  2013-12-31         MQ               3271    ORD  IND           830
# 6369479  2013-12-31         MQ               3272    CLE  LGA          1050
# 6369480  2013-12-31         MQ               3272    LGA  CLE           825
# 6369481  2013-12-31         MQ               3273    CMI  ORD           905
#
# ...

# %%
data_2014 = pd.read_csv('2014.csv')
data_2014
# Out:
#             FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0        2014-01-01         AA               2377    ICT  DFW          1135
# 1        2014-01-01         AA               2378    MIA  TPA          2225
# 2        2014-01-01         EV               2500    DFW  HOU          2105
# 3        2014-01-01         EV               2502    CRW  DFW          1655
# 4        2014-01-01         EV               2502    DFW  CRW          1320
# ...             ...        ...                ...    ...  ...           ...
# 5819806  2014-12-31         MQ               3552    RDU  LGA           640
# 5819807  2014-12-31         MQ               3555    CMH  ORD           720
# 5819808  2014-12-31         MQ               3564    GSO  LGA          1010
# 5819809  2014-12-31         MQ               3611    CAE  DFW           600
# 5819810  2014-12-31         MQ               3612    CLL  DFW          1120
#
# ...

# %%
data_2015 = pd.read_csv('2015.csv')
data_2015
# Out:
#             FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0        2015-01-01         NK                195    MCO  FLL          2147
# 1        2015-01-01         NK                197    LGA  FLL          1050
# 2        2015-01-01         NK                198    FLL  MCO           700
# 3        2015-01-01         NK                199    IAH  LAS          2240
# 4        2015-01-01         NK                200    IAH  ORD           623
# ...             ...        ...                ...    ...  ...           ...
# 5819074  2015-12-31         MQ               3058    ORD  ABQ          1015
# 5819075  2015-12-31         MQ               3059    DFW  LCH          1210
# 5819076  2015-12-31         MQ               3059    LCH  DFW          1358
# 5819077  2015-12-31         MQ               3060    DFW  FAR          1830
# 5819078  2015-12-31         MQ               3061    LCH  DFW           630
#
# ...

# %%
data_2016 = pd.read_csv('2016.csv')
data_2016
# Out:
#             FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0        2016-01-01         DL               1248    DTW  LAX          1935
# 1        2016-01-01         DL               1251    ATL  GRR          2125
# 2        2016-01-01         DL               1254    LAX  ATL          2255
# 3        2016-01-01         DL               1255    SLC  ATL          1656
# 4        2016-01-01         DL               1256    BZN  MSP           900
# ...             ...        ...                ...    ...  ...           ...
# 5617653  2016-12-31         NK                112    IAH  BWI           615
# 5617654  2016-12-31         NK                113    BWI  IAH          2108
# 5617655  2016-12-31         NK                121    ORD  RSW           700
# 5617656  2016-12-31         NK                124    RSW  ORD          1704
# 5617657  2016-12-31         NK                126    FLL  MYR          2015
#
# ...

# %%
data_2017 = pd.read_csv('2017.csv')
data_2017
# Out:
#             FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0        2017-01-01         AA                  1    JFK  LAX           800
# 1        2017-01-01         AA                  2    LAX  JFK           900
# 2        2017-01-01         AA                  4    LAX  JFK          1130
# 3        2017-01-01         AA                  5    DFW  HNL          1135
# 4        2017-01-01         AA                  6    OGG  DFW          1855
# ...             ...        ...                ...    ...  ...           ...
# 5674616  2017-12-31         UA               2421    IAH  LAS           750
# 5674617  2017-12-31         UA               2425    RSW  ORD          1611
# 5674618  2017-12-31         UA               2426    SNA  DEN          1335
# 5674619  2017-12-31         UA               2427    LAS  SFO          1115
# 5674620  2017-12-31         UA               2429    EWR  DEN          1510
#
# ...

# %%
data_2018 = pd.read_csv('2018.csv')
data_2018
# Out:
#             FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0        2018-01-01         UA               2429    EWR  DEN          1517
# 1        2018-01-01         UA               2427    LAS  SFO          1115
# 2        2018-01-01         UA               2426    SNA  DEN          1335
# 3        2018-01-01         UA               2425    RSW  ORD          1546
# 4        2018-01-01         UA               2424    ORD  ALB           630
# ...             ...        ...                ...    ...  ...           ...
# 7213441  2018-12-31         AA               1815    DCA  CLT          1534
# 7213442  2018-12-31         AA               1816    CLT  DFW          1751
# 7213443  2018-12-31         AA               1817    CLT  MEM          2015
# 7213444  2018-12-31         AA               1818    CLT  RDU          1300
# 7213445  2018-12-31         AA               1818    RDU  CLT          1435
#
# ...

# %%
data = pd.concat([data_2009, data_2010, data_2011,data_2012,data_2013,data_2014,data_2015,data_2016,data_2017,data_2018])

# %%
data
# Out:
#             FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0        2009-01-01         XE               1204    DCA  EWR        1100.0
# 1        2009-01-01         XE               1206    EWR  IAD        1510.0
# 2        2009-01-01         XE               1207    EWR  DCA        1100.0
# 3        2009-01-01         XE               1208    DCA  EWR        1240.0
# 4        2009-01-01         XE               1209    IAD  EWR        1715.0
# ...             ...        ...                ...    ...  ...           ...
# 7213441  2018-12-31         AA               1815    DCA  CLT        1534.0
# 7213442  2018-12-31         AA               1816    CLT  DFW        1751.0
# 7213443  2018-12-31         AA               1817    CLT  MEM        2015.0
# 7213444  2018-12-31         AA               1818    CLT  RDU        1300.0
# 7213445  2018-12-31         AA               1818    RDU  CLT        1435.0
#
# ...

# %%
data.isnull().sum()
# Out:
# FL_DATE                       0
# OP_CARRIER                    0
# OP_CARRIER_FL_NUM             0
# ORIGIN                        0
# DEST                          0
# CRS_DEP_TIME                  1
# DEP_TIME                 935723
# DEP_DELAY                940675
# TAXI_OUT                 963901
# WHEELS_OFF               963896
# WHEELS_ON                997016
# TAXI_IN                  997015
# CRS_ARR_TIME                  2
# ARR_TIME                 997015
# ARR_DELAY               1121351
# CANCELLED                     0
# CANCELLATION_CODE      60583755
# DIVERTED                      0
# CRS_ELAPSED_TIME             60
# ACTUAL_ELAPSED_TIME     1118754
# AIR_TIME                1118753
# DISTANCE                      0
# CARRIER_DELAY          50166224
# WEATHER_DELAY          50166224
# NAS_DELAY              50166224
# SECURITY_DELAY         50166224
# LATE_AIRCRAFT_DELAY    50166224
# Unnamed: 27            61556964
# dtype: int64

# %%
data.to_csv('data.csv',index=False)

# %%
61556964-11390402
# Out:
# 50166562
